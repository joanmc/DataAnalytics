# %%
import pandas as pd

df = pd.read_csv('CombinedFinalDublin2.csv')
df= df.drop('Unnamed: 0', 1)
df.head(32)
# Out:
#         Garda Station  Theft  Assault & Kidnapping  Fraud & Drugs & Weapons  \
# 0          Balbriggan    193                   168                      179
# 1         Ballyfermot    272                   173                      349
# 2            Ballymun    189                   217                      260
# 3   BlackrockCoDublin    243                   106                      156
# 4      Blanchardstown    790                   543                      579
# 5     BridewellDublin    279                   174                      299
# 6          Cabinteely    230                    83                       74
# 7               Cabra    172                   130                      157
# 8            Clontarf    415                    99                      113
# 9             Coolock    403                   279                      608
# 10         Donnybrook    299                   102                       77
# ...

# %%
print(list(df))
# Out:
# ['Garda Station', 'Theft', 'Assault & Kidnapping', 'Fraud & Drugs & Weapons', 'Environment & Public Order', 'PopulationTotalMale', 'PopulationTotalFemale', 'PopulationTotal', 'PrincipalStatusAtWork', 'PrincipalStatusLookingForFirstJob', 'PrincipalStatusUnemployed', 'PrincipalStatusStudent', 'PrincipalStatusLookingAfterHome/Family', 'PrincipalStatusRetired', 'PrincipalStatusUnableToWork', 'PrincipalStatusOther', 'SocialClassProfessionalWorkers', 'SocialClassManagerialAndTechnical', 'SocialClassNonManual', 'SocialClassSkilledManual', 'SocialClassSemiSkilled', 'SocialClassUnskilled', 'SocialClassOther', 'AgeEducationCeasedUnder15', 'AgeEducationCeasedAge15', 'AgeEducationCeasedAge16', 'AgeEducationCeasedAge17', 'AgeEducationCeasedAge18', 'AgeEducationCeasedAge19', 'AgeEducationCeasedAge20', 'AgeEducationCeasedAge21+', 'AgeEducationCeasedNotStated', 'EducationNotCeasedStillAtSchool', 'EducationNotCeasedOther', 'HighestLevelEducationNoFormalEducation', 'HighestLevelEducationPrimary', 'Hig
# ...

# %%
"""df_per5000 = df[['Garda Station', 'PopulationTotal', 'PopulationDensity', 'Green']]
df_per5000['Theft'] =  (df['Theft']/df['PopulationTotal'] * 5000)
df_per5000['Assault&Kidnapping'] =  (df['Assault & Kidnapping']/df['PopulationTotal'] * 5000)
df_per5000['Fraud&Drugs&Weapons'] =  (df['Fraud & Drugs & Weapons']/df['PopulationTotal'] * 5000)
df_per5000['Environment&PublicOrder'] =  (df['Environment & Public Order']/df['PopulationTotal'] * 5000)
df_per5000['PrincipalStatusAtWork'] =  (df['PrincipalStatusAtWork']/df['PopulationTotal'] * 5000)
df_per5000['PrincipalStatusLookingForFirstJob'] =  (df['PrincipalStatusLookingForFirstJob']/df['PopulationTotal'] * 5000)
df_per5000['PrincipalStatusUnemployed'] =  (df['PrincipalStatusUnemployed']/df['PopulationTotal'] * 5000)
df_per5000['PrincipalStatusStudent'] =  (df['PrincipalStatusStudent']/df['PopulationTotal'] * 5000)
df_per5000['PrincipalStatusLookingAfterHome/Family'] =  (df['PrincipalStatusLookingAfterHome/Family']/df['PopulationTotal'] * 5000)
df_per5000['PrincipalStatusUnableToWork'] =  (df['PrincipalStatusUnableToWork']/df['PopulationTotal'] * 5000)
df_per5000['PrincipalStatusOther'] =  (df['PrincipalStatusOther']/df['PopulationTotal'] * 5000)
df_per5000['AgeEducationCeasedNotStated'] =  (df['AgeEducationCeasedNotStated']/df['PopulationTotal'] * 5000)
df_per5000['HighestLevelEducationNotStated'] =  (df['HighestLevelEducationNotStated']/df['PopulationTotal'] * 5000)
df_per5000['GeneralHealthNotStated'] =  (df['GeneralHealthNotStated']/df['PopulationTotal'] * 5000)
df_per5000['NoLowEducation'] =  (df['NoLowEducation']/df['PopulationTotal'] * 5000)
df_per5000['MiddleEducation'] =  (df['MiddleEducation']/df['PopulationTotal'] * 5000)
df_per5000['NoLowEducation'] =  (df['NoLowEducation']/df['PopulationTotal'] * 5000)
df_per5000['HighEducation'] =  (df['HighEducation']/df['PopulationTotal'] * 5000)
df_per5000['LowerSocialClass'] =  (df['LowerSocialClass']/df['PopulationTotal'] * 5000)
df_per5000['HigherSocialClass'] =  (df['HigherSocialClass']/df['PopulationTotal'] * 5000)
df_per5000['EducationCeasedYoung'] =  (df['EducationCeasedYoung']/df['PopulationTotal'] * 5000)
df_per5000['ContinuedEducation'] =  (df['ContinuedEducation']/df['PopulationTotal'] * 5000)
df_per5000['StillinEducation'] =  (df['StillinEducation']/df['PopulationTotal'] * 5000)
df_per5000['EducationCeasedYoung'] =  (df['EducationCeasedYoung']/df['PopulationTotal'] * 5000)
df_per5000['GoodHealth'] =  (df['GoodHealth']/df['PopulationTotal'] * 5000)
df_per5000['PoorHealth'] =  (df['PoorHealth']/df['PopulationTotal'] * 5000)
df_per5000['TotalCrime'] =  (df['TotalCrime']/df['PopulationTotal'] * 5000)"""




# Green per 5000?
# Area per 5000?
# U18 M, F, Total ?

df.head()
# Out:
#        Garda Station      Theft  Assault & Kidnapping  \
# 0         Balbriggan  40.138092             34.938857
# 1        Ballyfermot  49.312883             31.364444
# 2           Ballymun  43.598616             50.057670
# 3  BlackrockCoDublin  37.994871             16.573895
# 4     Blanchardstown  40.274068             27.682049
#
#    Fraud & Drugs & Weapons  Environment & Public Order  PopulationTotalMale  \
# 0                37.226520                   97.745612          2442.808419
# 1                63.272780                  148.663838          2401.646180
# 2                59.976932                  173.471742          2400.922722
# 3                24.391769                   55.350554          2345.831509
# 4                29.517323                  106.241971          2456.820082
#
#    PopulationTotalFemale  PopulationTotal  PrincipalStatusAtWork  \
# 0            2557.191581            24042            1911.446635
# ...

# %%
df['GreensPerKMSQ'] = df['Green']/df['Area']
df['GreensPerPerson'] = df['Green']/df['PopulationTotal']
df['TotalCrime'] = df[df[1:4]].sum(axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-eee22379beef> in <module>()
#       1 df['GreensPerKMSQ'] = df['Green']/df['Area']
#       2 df['GreensPerPerson'] = df['Green']/df['PopulationTotal']
# ----> 3 df['TotalCrime'] = df[df[1:4]].sum(axis=1)
#
# /Users/JoanMcCarthy/anaconda/envs/comp47350/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1986             return self._getitem_array(key)
#    1987         elif isinstance(key, DataFrame):
# -> 1988             return self._getitem_frame(key)
#    1989         elif is_mi_columns:
#    1990             return self._getitem_multilevel(key)
#
# /Users/JoanMcCarthy/anaconda/envs/comp47350/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_frame(self, key)
#    2061     def _getitem_frame(self, key):
# ...

# %%
df.keys()
# Out:
# Index(['Garda Station', 'Theft', 'Assault & Kidnapping',
#        'Fraud & Drugs & Weapons', 'Environment & Public Order',
#        'PopulationTotalMale', 'PopulationTotalFemale', 'PopulationTotal',
#        'PrincipalStatusAtWork', 'PrincipalStatusLookingForFirstJob',
#        'PrincipalStatusUnemployed', 'PrincipalStatusStudent',
#        'PrincipalStatusLookingAfterHome/Family', 'PrincipalStatusRetired',
#        'PrincipalStatusUnableToWork', 'PrincipalStatusOther',
#        'SocialClassProfessionalWorkers', 'SocialClassManagerialAndTechnical',
#        'SocialClassNonManual', 'SocialClassSkilledManual',
#        'SocialClassSemiSkilled', 'SocialClassUnskilled', 'SocialClassOther',
#        'AgeEducationCeasedUnder15', 'AgeEducationCeasedAge15',
#        'AgeEducationCeasedAge16', 'AgeEducationCeasedAge17',
#        'AgeEducationCeasedAge18', 'AgeEducationCeasedAge19',
#        'AgeEducationCeasedAge20', 'AgeEducationCeasedAge21+',
# ...

# %%
df.to_csv('PerCapita.csv')
